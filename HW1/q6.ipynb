# %%
import networkx as nx
graph = nx.readwrite.edgelist.read_edgelist('./Wiki-Vote.txt')
hits = nx.hits(graph)

# %%
sorted_hits_0 = [(k, hits[0][k]) for k in sorted(hits[0], key=hits[0].get, reverse=True)]
sorted_hits_1 = [(k, hits[1][k]) for k in sorted(hits[1], key=hits[1].get, reverse=True)]

# %%
sorted_hits_0
# Out:
# [('2565', 0.004128549810305316),
#  ('766', 0.0034074446460947406),
#  ('1549', 0.0033874685425918766),
#  ('1166', 0.003128715151291178),
#  ('2688', 0.002882045769200612),
#  ('457', 0.002879632709260588),
#  ('3352', 0.002403286078770805),
#  ('11', 0.0023448683051184144),
#  ('1151', 0.002282388818791457),
#  ('1374', 0.0022758505917454355),
#  ('2485', 0.002194294709841801),
#  ('3456', 0.0021927566061846963),
#  ('2871', 0.0020944603412224676),
#  ('2328', 0.002055640838101163),
#  ('5524', 0.001933892980677254),
#  ('737', 0.0019122202420227042),
#  ('2237', 0.0018714749616995285),
#  ('2398', 0.0018630640720952714),
#  ('2651', 0.0018577322015155822),
#  ('3453', 0.001831293733505526),
#  ('2972', 0.001751937917744788),
#  ('1133', 0.0017496571029606094),
#  ('5079', 0.0017284293352724089),
#  ('4310', 0.001695947186504239),
#  ('2576', 0.0016812047567468927),
#  ('1608', 0.0016567219174825768),
#  ('4037', 0.0016535501756083171),
#  ('1305', 0.0016245825181967477),
# ...

# %%
pagerank = nx.pagerank(graph)

# %%
sorted_pagerank = [(k, pagerank[k]) for k in sorted(pagerank, key=pagerank.get, reverse=True)]

# %%
sorted_pagerank
# Out:
# [('2565', 0.004328848206376884),
#  ('11', 0.003012437685962262),
#  ('766', 0.0029604248476958563),
#  ('457', 0.002956712367016678),
#  ('4037', 0.0028851661587972837),
#  ('1549', 0.002851831750051357),
#  ('1166', 0.002662380592277932),
#  ('2688', 0.0023760691611198165),
#  ('15', 0.0021658490837085757),
#  ('1374', 0.002127955573315815),
#  ('2237', 0.0021132597670347896),
#  ('5524', 0.002075751857602307),
#  ('1151', 0.0020200756779749653),
#  ('3352', 0.0019525879232285524),
#  ('737', 0.0018868726207002299),
#  ('2328', 0.0018601116715127887),
#  ('5079', 0.0017342053492529527),
#  ('5802', 0.0017277014769055614),
#  ('2485', 0.0017068104823183216),
#  ('2871', 0.0016614669704038119),
#  ('2398', 0.0016493476671701208),
#  ('3456', 0.0016261083095514882),
#  ('2651', 0.0016034014576339762),
#  ('2972', 0.0015987181698694248),
#  ('1608', 0.0015832488060724692),
#  ('4310', 0.0015738804387148855),
#  ('1133', 0.0015738664156205622),
#  ('2625', 0.0015681746421418413),
# ...
